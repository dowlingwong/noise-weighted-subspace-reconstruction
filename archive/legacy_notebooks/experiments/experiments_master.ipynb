# %% [markdown]
# # Experiments Master Notebook
#
# **Paper:** *A Unified Maximum-Likelihood Framework for Signal Reconstruction:*
# *From Optimal Filtering to Noise-Aware Linear Autoencoders*
#
# Consolidated notebook replacing all individual `block_0X` notebooks.
#
# **Sections:**
# 0. Setup
# 1. Experiment-to-claim map
# 2. Preprocessing contract & PSD audit
# 3. E1 — Theorem 1: rank-1 EMPCA ≡ Optimal Filter
# 4. E2 — Theorem 2: noise-aware AE ≡ EMPCA
# 5. E3 — χ²(k) monotone / rank saturation
# 6. E4 — Cramér-Rao bound
# 7. E5 — Energy-resolution scaling (error bars)
# 8. E6 — Noise-aware vs isotropic PCA ablation (error bars)
# 9. E7 — Template mismatch bias curve
# 10. E8 — Time-shift optimal filter
# 11. E9 — EMPCA convergence
# 12. Figure summary
#
# **Workflow:**
# Run `python implementation/generate_data.py --n_events 1000` first (populates `results/data_cache.h5`,
# 8 seeds × all experiments, ~20-40 min).
# If the cache is absent the notebook falls back to a single-seed inline run automatically.

# %% [markdown]
# ## 0 — Setup

# %%
from pathlib import Path
import sys, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import h5py

warnings.filterwarnings('ignore', category=RuntimeWarning)

def find_repo_root(start: Path = Path.cwd()) -> Path:
    for p in [start, *start.parents]:
        if (p / 'QP_simulator').exists() and (p / 'implementation').exists():
            return p
    raise RuntimeError(f'Cannot locate repo root from {start}')

REPO    = find_repo_root()
for _p in [REPO, REPO/'src', REPO/'QP_simulator', REPO/'implementation']:
    if str(_p) not in sys.path:
        sys.path.insert(0, str(_p))

CACHE_H5 = REPO / 'results' / 'data_cache.h5'
FIG_DIR  = REPO / 'results' / 'figures'
FIG_DIR.mkdir(parents=True, exist_ok=True)

print('Repo root :', REPO)
print('Cache h5  :', CACHE_H5, '— exists:', CACHE_H5.exists())
# Out:
# Repo root : /Users/wongdowling/Documents/noise-weighted-subspace-reconstruction
# Cache h5  : /Users/wongdowling/Documents/noise-weighted-subspace-reconstruction/results/data_cache.h5 — exists: True

# %%
mpl.rcParams.update({
    'font.family': 'serif', 'font.size': 11,
    'axes.titlesize': 11, 'axes.labelsize': 11,
    'figure.dpi': 150, 'lines.linewidth': 1.6,
    'axes.grid': True, 'grid.alpha': 0.3,
})
BLUE, ORANGE, GREEN, RED = '#1f77b4', '#ff7f0e', '#2ca02c', '#d62728'

def save_fig(fig, name):
    path = FIG_DIR / name
    fig.savefig(path, bbox_inches='tight', dpi=150)
    print(f'  saved -> {path.relative_to(REPO)}')

def load_df(h5, path):
    grp = h5[path]
    d = {}
    for k in grp.keys():
        item = grp[k]
        if isinstance(item, h5py.Group):
            continue   # skip nested sub-groups (e.g. e7/curve)
        v = item[()]
        if v.dtype.kind == 'S':
            v = np.array([x.decode() for x in v])
        d[k] = v
    return pd.DataFrame(d)

def cache_groups(h5, prefix):
    return sorted(h5[prefix].keys()) if prefix in h5 else []

def mean_std(arr):
    mu = arr.mean(0)
    sd = arr.std(0, ddof=1) if arr.shape[0] > 1 else np.zeros_like(mu)
    return mu, sd

print('Helpers ready.')
# Out:
# Helpers ready.

# %%
# Single-seed fallback when cache is absent
if not CACHE_H5.exists():
    print('Cache not found — running single-seed fallback (~2-5 min)...')
    from notebook_support import (
        CanonicalConfig, run_block04_theorem_suite,
        run_block05_bridge_suite, run_block06_convergence_suite,
        run_block07_ablation_suite,
    )
    _cfg = CanonicalConfig(seed=314159, sim_events_medium=1000,
                           sim_events_large=1000).validate()
    _fb = {
        'b04': run_block04_theorem_suite(_cfg),
        'b05': run_block05_bridge_suite(_cfg),
        'b06': run_block06_convergence_suite(_cfg),
        'b07': run_block07_ablation_suite(_cfg),
    }
    print('Fallback done.')
else:
    _fb = None
    print('Using h5 cache.')
# Out:
# Using h5 cache.

# %% [markdown]
# ---
# ## 1 — Experiment-to-claim map
#
# Every plot in this notebook is anchored to a specific theorem, proposition,
# or empirical claim in the paper.  The table below is the authoritative mapping
# (generated from `notebook_support.dataframe_from_claim_map`).
#
# ### Design rules
#
# - Each experiment carries a **support regime**: `theorem-support`, `real-support`, or `robustness-support`.
# - Acceptance criteria are **explicit numeric thresholds** — no vague phrases.
# - Structured-noise studies (E10, E11) are `robustness-support` unless there is a specific reason otherwise.
#
# ### Naming conventions
#
# | Concept | Convention |
# |---|---|
# | Simulated rank-1 batch | `SIM-rank1` |
# | Simulated controlled family | `SIM-controlled-family` |
# | Rank label | `k{integer}` |
# | Seed label | `seed_{integer}` |
# | Figures | `results/figures/*.jpg` |
# | Cache | `results/data_cache.h5` |

# %%
from notebook_support import dataframe_from_claim_map, CanonicalConfig, config_as_frame

claim_map = dataframe_from_claim_map()
pd.set_option('display.max_colwidth', 90)
display(claim_map[['experiment_id', 'claim', 'paper_anchor', 'support_regime', 'metrics']])
print(f'\n{len(claim_map)} experiments mapped.')
# Out:
#    experiment_id                                                      claim  \
# 0             E1                      rank-1 EMPCA ≡ OF amplitude estimator
# 1             E2                              noise-aware linear AE ≡ EMPCA
# 2             E3                 chi^2(k) decreases monotonically with rank
# 3             E4                                           CRB variance law
# 4             E5                              energy-resolution scaling law
# 5             E6  noise-aware EMPCA beats isotropic PCA under colored noise
# 6             E7                 template mismatch bias and rank-2 recovery
# 7             E8                   time-shift OF recovers jittered arrivals
# 8             E9                              EMPCA convergence diagnostics
# 9            E10                            non-stationary noise robustness
# 10           E11               artifact robustness and refit after flagging
# 11           E12                                  real K-alpha verification
#
#                                 paper_anchor      support_regime  \
# 0                       04_empca / theorem 1     theorem-support
# 1                   05_linear_ae / theorem 2     theorem-support
# 2              04_empca / rank-k proposition     theorem-support
# 3                    03_optimal_filter / CRB     theorem-support
# 4             03_optimal_filter / resolution               mixed
# 5                  07_experiments / ablation     theorem-support
# 6      03_optimal_filter / template mismatch     theorem-support
# 7             03_optimal_filter / shifted OF     theorem-support
# 8       06_convergence / convergence theorem     theorem-support
# 9   06_convergence / stationarity discussion  robustness-support
# 10              06_convergence / limitations  robustness-support
# 11   07_experiments / real data verification        real-support
#
#                                                                                       metrics
# 0   weighted cosine; amplitude correlation; median relative amplitude error; residual KS p...
# 1                  principal-angle cosines for k=1..3; residual mean gap; residual KS p-value
# 2                                 held-out weighted residual by k for 1D and multi-D families
# 3                               empirical amplitude variance vs 1 / N_Phi across noise colors
# 4               sigma_E vs noise power slope; simulated residuals; real-data sigma comparison
# 5                                    weighted residual gain under white, pink, brownian noise
# 6                                              mean amplitude bias; RMSE; bias-vs-cos^2 curve
# 7                                      arrival-time RMSE; amplitude RMSE; fixed-vs-shift bias
# 8                          chi^2 trace monotonicity; iterations to tolerance; init dependence
# 9                                            global-vs-segment PSD RMSE and weighted residual
# 10                                 amplitude RMSE and weighted residual before/after flagging
# 11         rank-1 cosine; AE bridge cosines; Gaussian amplitude histogram; sigma_A comparison
# 12 experiments mapped.

# %%
# Canonical config — single source of truth for all hyperparameters
cfg = CanonicalConfig().validate()
display(config_as_frame(cfg))
# Out:
#                        setting                            value
# 0                         seed                           314159
# 1           sampling_frequency                         250000.0
# 2                    trace_len                            32768
# 3                   pretrigger                             4000
# 4                  split_train                              0.6
# 5                    split_val                              0.2
# 6                   split_test                              0.2
# 7           empirical_rank_max                                8
# 8           default_empca_iter                               60
# 9       default_empca_patience                               12
# 10  default_psd_floor_quantile                             0.01
# 11              real_train_cap                              512
# 12               real_eval_cap                              384
# 13            sim_events_small                              128
# 14           sim_events_medium                              160
# 15            sim_events_large                              192
# 16              crb_replicates                             1200
# 17          results_tables_dir                   results/tables
# 18         results_figures_dir                  results/figures
# 19       results_manifests_dir                results/manifests
# 20       results_notebooks_dir                results/notebooks
# 21             real_trace_path           data/k_alpha/k_alpha_traces.h5
# 22                real_rq_path              data/k_alpha/k_alpha_rqs.h5
# 23               template_path  data/template_K_alpha_tight.npy
# 24          canonical_psd_path   data/weight/noise_psd_pink.npy

# %% [markdown]
# ---
# ## 2 — Preprocessing contract and PSD audit
#
# Freezes the analysis interface shared by all experiments.
# Requires real K-alpha data (`data/k_alpha/k_alpha_traces.h5`).
# If that file is absent, falls back to showing the analytic pink PSD used for simulations.
#
# ### Preprocessing decisions
#
# | Decision | Value |
# |---|---|
# | Baseline window | pretrigger samples (default 4000) |
# | Baseline method | per-event mean subtraction |
# | Trace length | 32768 samples |
# | Train / val / test split | 60 / 20 / 20, seed-fixed |
# | Frequency transform | one-sided `rfft`, normalised by N |
# | PSD | Welch on pretrigger windows; floored at 1st percentile |
# | Weights | `w_k = 1 / J_k`; DC bin zeroed |
# | Template normalisation | peak-aligned; unit peak |
# | Whitening | element-wise division by `sqrt(J_k)` |
# | Covariance model | diagonal (Toeplitz + stationarity) |

# %%
try:
    from notebook_support import run_block02_audit
    _audit = run_block02_audit(cfg)
    bundle = _audit['bundle']
    display(_audit['audit_df'])
    display(_audit['reports_df'])

    fig, ax = plt.subplots(figsize=(6, 3.8))
    freqs = bundle.metadata['empirical_psd_freqs']
    emp   = bundle.metadata['empirical_psd']
    ax.loglog(freqs[1:], bundle.psd_one_sided[1:], color=BLUE,
              label='canonical PSD')
    ax.loglog(freqs[1:], emp[1:], color=ORANGE, ls='--',
              label='empirical pretrigger PSD')
    ax.set_xlabel('frequency [Hz]'); ax.set_ylabel('PSD')
    ax.set_title('PSD audit — real K-alpha data')
    ax.legend(fontsize=9); fig.tight_layout()
    save_fig(fig, 'psd_audit.jpg'); plt.show()

except FileNotFoundError as _e:
    print(f'Real data not found ({_e}).')
    print('Showing analytic pink PSD used for simulations instead.')
    from notebook_support import stationary_noise_generator
    ng = stationary_noise_generator(cfg, noise_type='pink', noise_power=1.0)
    freqs, psd = ng.build_psd(cfg.trace_len)
    fig, ax = plt.subplots(figsize=(6, 3.8))
    ax.loglog(freqs[1:], psd[1:], color=BLUE, label='analytic pink PSD (simulation)')
    ax.set_xlabel('frequency [Hz]'); ax.set_ylabel('PSD')
    ax.set_title('Simulation PSD (real K-alpha data absent)')
    ax.legend(fontsize=9); fig.tight_layout()
    save_fig(fig, 'psd_audit_simulation.jpg'); plt.show()
# Out:
# Real data not found ([Errno 2] Unable to open file (unable to open file: name = '/Users/wongdowling/Documents/noise-weighted-subspace-reconstruction/data/k_alpha/k_alpha_traces.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)).
# Showing analytic pink PSD used for simulations instead.
#   saved -> results/figures/psd_audit_simulation.jpg

# %% [markdown]
# ---
# ## 3 — E1: Theorem 1 — rank-1 EMPCA ≡ Optimal Filter
#
# *Paper §4.3, Table 1 in §3.*
#
# **Pass criteria:** ρ_w > 0.9999 · amp correlation > 0.999 · median rel error < 1e-3 · KS p > 0.05

# %%
e1_rows = []
if CACHE_H5.exists():
    with h5py.File(CACHE_H5, 'r') as h5:
        for sg in cache_groups(h5, 'e1_e4_e5'):
            path = f'e1_e4_e5/{sg}/e1'
            if path in h5:
                df = load_df(h5, path); df['seed'] = sg; e1_rows.append(df)

if not e1_rows and _fb:
    e1_rows = [_fb['b04']['rank1_summary_df'].assign(seed='fallback')]

e1_all = pd.concat(e1_rows, ignore_index=True)

THRESHOLDS = {
    'weighted_subspace_cosine': (0.9999, '>='),
    'amplitude_correlation':    (0.999,  '>='),
    'median_relative_error':    (1e-3,   '<='),
    'residual_ks_pvalue':       (0.05,   '>='),
}
numeric = [c for c in THRESHOLDS if c in e1_all.columns]
smry = e1_all[numeric].agg(['mean', 'std']).T
for col, (thr, op) in THRESHOLDS.items():
    if col not in smry.index: continue
    mu = smry.loc[col, 'mean']
    smry.loc[col, 'threshold'] = thr
    smry.loc[col, 'pass'] = 'PASS' if (mu >= thr if op == '>=' else mu <= thr) else 'FAIL'
display(smry)
# Out:
#                               mean           std  threshold  pass
# weighted_subspace_cosine  0.999419  6.745726e-06     0.9999  FAIL
# amplitude_correlation     1.000000  7.024390e-08     0.9990  PASS
# median_relative_error     0.001147  2.996271e-05     0.0010  FAIL
# residual_ks_pvalue        1.000000  5.453210e-07     0.0500  PASS

# %%
# ── E1: amplitude parity scatter / correlation bar chart ─────────────────────
# Shows EMPCA-vs-OF amplitude agreement.
# Raw amplitude arrays are NOT saved to H5 (only summary stats are stored).
# Falls back gracefully to amplitude_correlation bar chart per seed.

if e1_all is not None and 'of_amplitude' in e1_all.columns:
    fig, ax = plt.subplots(figsize=(4.5, 4.5))
    ax.scatter(e1_all['of_amplitude'], e1_all['empca_amplitude'],
               s=3, alpha=0.3, color=BLUE, rasterized=True)
    lo = min(e1_all['of_amplitude'].min(), e1_all['empca_amplitude'].min())
    hi = max(e1_all['of_amplitude'].max(), e1_all['empca_amplitude'].max())
    ax.plot([lo, hi], [lo, hi], 'k--', lw=1, label='y = x')
    ax.set_xlabel('OF amplitude $\\hat{a}^{\\mathrm{OF}}$')
    ax.set_ylabel('EMPCA amplitude $\\hat{a}^{\\mathrm{EMPCA}}$')
    ax.set_title('E1 — Amplitude parity: rank-1 EMPCA vs OF')
    ax.legend(fontsize=9)
    r_val = float(np.corrcoef(e1_all['of_amplitude'], e1_all['empca_amplitude'])[0, 1])
    ax.text(0.05, 0.95, f'r = {r_val:.6f}', transform=ax.transAxes,
            va='top', fontsize=10)
    fig.tight_layout()
    save_fig(fig, 'e1_amplitude_parity.jpg')
    plt.show()
else:
    # H5 stores per-seed amplitude_correlation scalars, not raw amplitude vectors.
    print('Raw amplitude arrays not in H5; plotting amplitude_correlation per seed.')
    fig, ax = plt.subplots(figsize=(6, 3.8))
    seeds_e1 = e1_all['seed'].values
    corr_e1  = e1_all['amplitude_correlation'].values.astype(float)
    ax.bar(range(len(seeds_e1)), corr_e1, color=BLUE, alpha=0.85)
    ax.axhline(0.999, color='red', ls='--', lw=1, label='pass threshold 0.999')
    ax.set_xticks(range(len(seeds_e1)))
    ax.set_xticklabels([str(s)[-4:] for s in seeds_e1], rotation=45, fontsize=8)
    ax.set_xlabel('seed (last 4 digits)')
    ax.set_ylabel('amplitude_correlation  (OF vs EMPCA, per seed)')
    ax.set_title('E1 — Amplitude parity: OF vs EMPCA')
    ax.legend(fontsize=9); ax.set_ylim(0.99, 1.001)
    mu_corr = float(corr_e1.mean())
    ax.text(0.05, 0.05, f'mean r = {mu_corr:.6f}', transform=ax.transAxes,
            va='bottom', fontsize=10)
    fig.tight_layout()
    save_fig(fig, 'e1_amplitude_parity.jpg')
    plt.show()
# Out:
# Raw amplitude arrays not in H5; plotting amplitude_correlation per seed.
#   saved -> results/figures/e1_amplitude_parity.jpg

# %% [markdown]
# ---
# ## 4 — E2: Theorem 2 — noise-aware linear AE ≡ EMPCA
#
# *Paper §5.3.*
# **Pass criterion:** minimum principal-angle cosine > 0.9999 for k = 1, 2, 3.

# %%
e2_by_k = {}
if CACHE_H5.exists():
    with h5py.File(CACHE_H5, 'r') as h5:
        for sg in cache_groups(h5, 'e2'):
            path = f'e2/{sg}'
            if path not in h5: continue
            df = load_df(h5, path)
            if 'k' not in df.columns: continue
            for _, row in df.iterrows():
                e2_by_k.setdefault(int(row['k']), []).append(
                    float(row['min_principal_cosine']))

if not e2_by_k and _fb:
    bd = _fb['b05']['bridge_df'].copy()
    bd['min_pc'] = bd['principal_angle_cosines'].map(
        lambda x: min(x) if hasattr(x, '__iter__') else x)
    for _, r in bd.iterrows():
        e2_by_k.setdefault(int(r['k']), []).append(float(r['min_pc']))

ks    = sorted(e2_by_k)
mu_e2 = np.array([np.mean(e2_by_k[k]) for k in ks])
sd_e2 = np.array([np.std(e2_by_k[k], ddof=1) if len(e2_by_k[k]) > 1
                  else 0. for k in ks])

fig, ax = plt.subplots(figsize=(5.5, 3.8))
ax.errorbar(ks, mu_e2, yerr=sd_e2, fmt='o-', color=BLUE, capsize=4,
            label='min cosine (mean +/- std)')
ax.axhline(0.9999, color='gray', ls='--', lw=1, label='pass threshold 0.9999')
ax.set_xlabel('rank k'); ax.set_ylabel('minimum principal-angle cosine')
ax.set_ylim(0.998, 1.0005)
ax.set_title('E2 -- EMPCA vs exact weighted bridge')
ax.legend(fontsize=9); fig.tight_layout()
save_fig(fig, 'e2_bridge_cosines.jpg'); plt.show()
print('All k pass:', all(m >= 0.9999 for m in mu_e2))
# Out:
#   saved -> results/figures/e2_bridge_cosines.jpg
# All k pass: True

# %% [markdown]
# ---
# ## 5 — E3: Rank saturation — χ²(k) monotone decrease
#
# *Paper §4.4.*
# χ² must strictly decrease from k=1 to k=2 on the multi-dimensional family, then plateau.

# %%
e3_by_seed = {}
if CACHE_H5.exists():
    with h5py.File(CACHE_H5, 'r') as h5:
        for sg in cache_groups(h5, 'e3_e9'):
            path = f'e3_e9/{sg}/rank_summary'
            if path in h5:
                e3_by_seed[sg] = load_df(h5, path)

if not e3_by_seed and _fb:
    e3_by_seed['fallback'] = (
        _fb['b06']['rank_summary_df'][['k', 'chi2_proxy_mean', 'chi2_proxy_std']]
        .copy())

ks_e3   = sorted(list(e3_by_seed.values())[0]['k'].astype(int))
chi2stk = np.stack([df.sort_values('k')['chi2_proxy_mean'].values
                    for df in e3_by_seed.values()], axis=0)
mu_c, sd_c = mean_std(chi2stk)

fig, ax = plt.subplots(figsize=(5.5, 3.8))
ax.errorbar(ks_e3, mu_c, yerr=sd_c, fmt='o-', color=BLUE, capsize=4,
            label='held-out chi2 (mean +/- std)')
ax.set_xlabel('rank k'); ax.set_ylabel('held-out weighted residual')
ax.set_title('E3 -- Rank saturation (multi-dimensional family)')
ax.legend(fontsize=9); fig.tight_layout()
save_fig(fig, 'e3_rank_saturation.jpg'); plt.show()
if len(mu_c) > 1:
    print(f'Delta chi2(1->2) / chi2(1) = {(mu_c[0]-mu_c[1])/mu_c[0]:.4f}')
# Out:
#   saved -> results/figures/e3_rank_saturation.jpg
# Delta chi2(1->2) / chi2(1) = 0.2000

# %% [markdown]
# ---
# ## 6 — E4: Cramér-Rao bound verification
#
# *Paper §3.2.*
# **Pass criterion:** |σ²_emp − 1/N_Φ| / (1/N_Φ) < 5% for each noise colour.

# %%
e4_rows = []
if CACHE_H5.exists():
    with h5py.File(CACHE_H5, 'r') as h5:
        for sg in cache_groups(h5, 'e1_e4_e5'):
            path = f'e1_e4_e5/{sg}/e4'
            if path in h5:
                df = load_df(h5, path); df['seed'] = sg; e4_rows.append(df)

if not e4_rows and _fb:
    e4_rows = [_fb['b04']['crb_df'].assign(seed='fallback')]

e4_all = pd.concat(e4_rows, ignore_index=True)
e4_agg = (e4_all.groupby('noise_type')['relative_error']
          .agg(['mean', 'std']).reset_index()
          .rename(columns={'mean': 'mean_rel_error', 'std': 'std_rel_error'}))
e4_agg['pass'] = e4_agg['mean_rel_error'].apply(
    lambda x: 'PASS' if x < 0.05 else 'FAIL')
display(e4_agg)

fig, ax = plt.subplots(figsize=(5, 3.5))
x = np.arange(len(e4_agg))
ax.bar(x, e4_agg['mean_rel_error'], yerr=e4_agg['std_rel_error'].fillna(0),
       capsize=5, color=BLUE, alpha=0.8,
       error_kw={'ecolor': 'black', 'lw': 1.5})
ax.axhline(0.05, color='red', ls='--', lw=1, label='5% threshold')
ax.set_xticks(x); ax.set_xticklabels(e4_agg['noise_type'])
ax.set_ylabel('|sigma2_emp - 1/N_Phi| / (1/N_Phi)')
ax.set_title('E4 -- CRB verification'); ax.legend(fontsize=9)
fig.tight_layout()
save_fig(fig, 'e4_crb_verification.jpg'); plt.show()
# Out:
#   noise_type  mean_rel_error  std_rel_error  pass
# 0   brownian        0.018183       0.014935  PASS
# 1       pink        0.030431       0.015968  PASS
# 2      white        0.035439       0.013358  PASS
#   saved -> results/figures/e4_crb_verification.jpg

# %% [markdown]
# ---
# ## 7 — E5: Energy-resolution scaling law
#
# *Paper §3.2.*
# σ_E ∝ (noise_power)^{1/2}.  Log-log slope should be 0.500 ± 0.05.
# Error bars = std across 8 seeds.

# %%
e5_emp = {}; e5_pred = {}; e5_pwr = {}
if CACHE_H5.exists():
    with h5py.File(CACHE_H5, 'r') as h5:
        for sg in cache_groups(h5, 'e1_e4_e5'):
            path = f'e1_e4_e5/{sg}/e5'
            if path not in h5: continue
            df = load_df(h5, path)
            e5_pwr[sg]  = df['noise_power'].values.astype(float)
            e5_emp[sg]  = df['sigma_emp'].values.astype(float)
            e5_pred[sg] = df['sigma_pred'].values.astype(float)

if not e5_emp and _fb:
    df = _fb['b04']['resolution_df']
    e5_pwr['fallback']  = df['noise_power'].values.astype(float)
    e5_emp['fallback']  = df['sigma_emp'].values.astype(float)
    e5_pred['fallback'] = df['sigma_pred'].values.astype(float)

powers         = list(e5_pwr.values())[0]
mu_emp, sd_emp = mean_std(np.stack(list(e5_emp.values()),  axis=0))
mu_prd, sd_prd = mean_std(np.stack(list(e5_pred.values()), axis=0))
slopes = [np.polyfit(np.log(p), np.log(s), 1)[0]
          for p, s in zip(e5_pwr.values(), e5_emp.values())]
slope_mu = float(np.mean(slopes))
slope_sd = float(np.std(slopes))

fig, ax = plt.subplots(figsize=(5.5, 4))
ax.errorbar(powers, mu_emp, yerr=sd_emp, fmt='o-', color=BLUE,
            capsize=4, label='sigma_emp (mean +/- std)')
ax.errorbar(powers, mu_prd, yerr=sd_prd, fmt='s--', color=ORANGE,
            capsize=4, label='sigma_pred = 1/sqrt(N_Phi)')
ax.set_xscale('log'); ax.set_yscale('log')
ax.set_xlabel('noise power'); ax.set_ylabel('sigma_E proxy')
ax.set_title('E5 -- Energy-resolution scaling')
ax.legend(fontsize=9)
ax.text(0.05, 0.95,
        f'log-log slope = {slope_mu:.3f} +/- {slope_sd:.3f}  (ideal 0.500)',
        transform=ax.transAxes, va='top', fontsize=9)
fig.tight_layout()
save_fig(fig, 'e5_resolution_scaling.jpg'); plt.show()
print(f'slope = {slope_mu:.4f}  pass: {abs(slope_mu - 0.5) < 0.05}')
# Out:
#   saved -> results/figures/e5_resolution_scaling.jpg
# slope = 0.5000  pass: True

# %% [markdown]
# ---
# ## 8 — E6: Noise-aware EMPCA vs isotropic PCA
#
# *Paper §7 — main practical result.*
# Expected: white noise → ~0 gap; pink/brownian → significant improvement.
# Error bars = std across seeds.

# %%
e6_by_seed = {}
if CACHE_H5.exists():
    with h5py.File(CACHE_H5, 'r') as h5:
        for sg in cache_groups(h5, 'e6_e7'):
            path = f'e6_e7/{sg}/e6'
            if path in h5:
                e6_by_seed[sg] = load_df(h5, path)

if not e6_by_seed and _fb:
    e6_by_seed['fallback'] = _fb['b07']['ablation_df'].copy()

noise_types = list(e6_by_seed.values())[0]['noise_type'].tolist()
ri_stk = np.stack(
    [df.set_index('noise_type').loc[noise_types, 'relative_improvement'].values
     for df in e6_by_seed.values()], axis=0)
mu_ri, sd_ri = mean_std(ri_stk)

fig, ax = plt.subplots(figsize=(5.5, 4))
x = np.arange(len(noise_types))
bar_colors = [BLUE, ORANGE, GREEN][:len(noise_types)]
ax.bar(x, mu_ri, yerr=sd_ri, capsize=6, color=bar_colors, alpha=0.85,
       error_kw={'ecolor': 'black', 'lw': 1.5})
ax.axhline(0, color='black', lw=0.8)
ax.set_xticks(x); ax.set_xticklabels(noise_types)
ax.set_ylabel('relative improvement  (chi2_iso - chi2_w) / chi2_iso')
ax.set_title('E6 -- Noise-aware vs isotropic loss')
for xi, (m, s) in enumerate(zip(mu_ri, sd_ri)):
    ax.text(xi, m + s + 0.005, f'{m:.3f}', ha='center', fontsize=8)
fig.tight_layout()
save_fig(fig, 'e6_ablation.jpg'); plt.show()
display(pd.DataFrame({'noise_type': noise_types,
                      'mean_improvement': mu_ri, 'std': sd_ri}))
# Out:
#   saved -> results/figures/e6_ablation.jpg
#   noise_type  mean_improvement       std
# 0      white          0.999410  0.000260
# 1       pink          0.946649  0.039946
# 2   brownian          0.978834  0.032463

# %%
# ── E6b: sigma_E comparison noise-aware vs isotropic ─────────────────────────
# Figure pre-generated via standalone script (3 seeds × 200 events).
# Skips recompute if PDF already present in results/figures/.
_e6b_fig = FIG_DIR / 'e6_sigma_E_comparison.jpg'
if _e6b_fig.exists():
    print(f'E6b figure already present: {_e6b_fig.name} — skipping recompute.')
else:
    from notebook_support import (exact_isotropic_subspace, rankk_gls_coefficients,
                                   fit_weighted_empca as fit_weighted_empca,
                                   simulate_rank1_batch as _srb6b)
    noise_types_e6b = ['pink', 'white', 'brownian']
    e6b_weighted = {nt: [] for nt in noise_types_e6b}
    e6b_iso      = {nt: [] for nt in noise_types_e6b}
    for seed in [314159, 271828, 161803]:
        _cfg_e6b = CanonicalConfig(seed=seed).validate()
        for nt in noise_types_e6b:
            bundle, _ = _srb6b(_cfg_e6b, n_events=200,
                amp_range=(1.0, 1.0), noise_type=nt, noise_power=1.0)
            tr = bundle.split_indices['train']; te = bundle.split_indices['test']
            w = bundle.weights_one_sided
            Xtr = bundle.traces_freq[tr]; Xte = bundle.traces_freq[te]
            r = fit_weighted_empca(Xtr, w, k=1, n_iter=20, patience=10)
            a_w = rankk_gls_coefficients(Xte, r['basis'], w, return_complex=False)[:,0]
            e6b_weighted[nt].append(float(np.std(a_w, ddof=1)))
            bi = exact_isotropic_subspace(Xtr, k=1)
            a_i = rankk_gls_coefficients(Xte, bi, np.ones_like(w), return_complex=False)[:,0]
            e6b_iso[nt].append(float(np.std(a_i, ddof=1)))
    mu_w = np.array([np.mean(e6b_weighted[nt]) for nt in noise_types_e6b])
    sd_w = np.array([np.std(e6b_weighted[nt])  for nt in noise_types_e6b])
    mu_i = np.array([np.mean(e6b_iso[nt])      for nt in noise_types_e6b])
    sd_i = np.array([np.std(e6b_iso[nt])       for nt in noise_types_e6b])
    x_e6b = np.arange(3); width_e6b = 0.35
    fig, ax = plt.subplots(figsize=(6, 4))
    ax.bar(x_e6b-width_e6b/2, mu_w, width_e6b, yerr=sd_w, capsize=5,
           color=BLUE, alpha=0.85, label='Noise-aware EMPCA', error_kw={'lw':1.5})
    ax.bar(x_e6b+width_e6b/2, mu_i, width_e6b, yerr=sd_i, capsize=5,
           color=ORANGE, alpha=0.85, label='Isotropic PCA', error_kw={'lw':1.5})
    ax.set_xticks(x_e6b); ax.set_xticklabels(noise_types_e6b)
    ax.set_ylabel(r'$\sigma_E$  (std of amplitude estimates)')
    ax.set_title('E6b — Energy resolution: noise-aware vs isotropic')
    ax.legend(fontsize=9); fig.tight_layout()
    save_fig(fig, 'e6_sigma_E_comparison.jpg'); plt.show()
# Out:
#   saved -> results/figures/e6_sigma_E_comparison.jpg

# %% [markdown]
# ---
# ## 9 — E7: Template mismatch bias
#
# *Paper §3.4.*
# When τ_decay differs from the nominal 3 ms, fixed-template OF is biased.
# Rank-2 EMPCA recovers amplitude.
#
# **Fix vs original block_07:** x-axis is τ (ms), not cos²(θ_w).
# Dual y-axes show the OF estimate and the subspace overlap as independent functions of τ.

# %%
e7_curve = {}
if CACHE_H5.exists():
    with h5py.File(CACHE_H5, 'r') as h5:
        for sg in cache_groups(h5, 'e6_e7'):
            path = f'e6_e7/{sg}/e7/curve'
            if path in h5:
                e7_curve[sg] = load_df(h5, path)

if not e7_curve and _fb:
    e7_curve['fallback'] = _fb['b07']['mismatch_curve_df'].copy()

ref    = list(e7_curve.values())[0].sort_values('tau_decay')
tau_ms = ref['tau_decay'].values / 1e6
cos2   = ref['cosine_squared'].values
of_est = ref['of_estimate_for_unit_shape'].values

fig, ax1 = plt.subplots(figsize=(6, 4))
ax2 = ax1.twinx()
ax1.plot(tau_ms, of_est, 'o-',  color=BLUE,   label='OF estimate (unit-shape input)')
ax2.plot(tau_ms, cos2,   's--', color=ORANGE, label='cos2(theta_w) subspace overlap')
ax1.axvline(3.0, color='gray', ls=':', lw=1)
ylo, yhi = ax1.get_ylim()
ax1.text(3.05, ylo + 0.02*(yhi-ylo), 'nominal tau = 3 ms',
         fontsize=8, color='gray')
ax1.set_xlabel('tau_decay (ms)')
ax1.set_ylabel('OF amplitude estimate (unit-shape input)', color=BLUE)
ax2.set_ylabel('cos2(theta_w)', color=ORANGE)
ax1.tick_params(axis='y', colors=BLUE)
ax2.tick_params(axis='y', colors=ORANGE)
l1, lb1 = ax1.get_legend_handles_labels()
l2, lb2 = ax2.get_legend_handles_labels()
ax1.legend(l1+l2, lb1+lb2, fontsize=8, loc='lower right')
ax1.set_title('E7 -- Template mismatch bias curve')
fig.tight_layout()
save_fig(fig, 'e7_mismatch_curve.jpg'); plt.show()
# Out:
#   saved -> results/figures/e7_mismatch_curve.jpg

# %%
# E7 method summary: OF vs EMPCA k=1 vs k=2
e7_rows = []
if CACHE_H5.exists():
    with h5py.File(CACHE_H5, 'r') as h5:
        for sg in cache_groups(h5, 'e6_e7'):
            path = f'e6_e7/{sg}/e7'
            if path in h5:
                df = load_df(h5, path); df['seed'] = sg; e7_rows.append(df)

if not e7_rows and _fb:
    e7_rows = [_fb['b07']['mismatch_df'].assign(seed='fallback')]

if e7_rows:
    e7_all = pd.concat(e7_rows, ignore_index=True)
    display(e7_all.groupby('method')[['mean_relative_bias', 'rmse']]
            .agg(['mean', 'std']))
# Out:
#            mean_relative_bias                 rmse
#                          mean       std       mean       std
# method
# EMPCA_k1            -0.005712  0.006397   8.196002  0.806920
# EMPCA_k2            -0.001073  0.002976   2.422895  0.243486
# OF_nominal          -0.138577  0.006090  22.049767  1.152158

# %% [markdown]
# ---
# ## 10 — E8: Time-shift optimal filter
#
# *Paper §3.2.*
# Time-shift OF scans a grid of shifted templates.  Arrival-time RMSE and amplitude bias should both improve over fixed-template OF.

# %%
e8_rows = []
if CACHE_H5.exists():
    with h5py.File(CACHE_H5, 'r') as h5:
        for sg in cache_groups(h5, 'e6_e7'):
            path = f'e6_e7/{sg}/e8'
            if path in h5:
                df = load_df(h5, path); df['seed'] = sg; e8_rows.append(df)

if not e8_rows and _fb:
    e8_rows = [_fb['b07']['shift_df'].assign(seed='fallback')]

if e8_rows:
    e8_all = pd.concat(e8_rows, ignore_index=True)
    display(e8_all.groupby('method')[['amplitude_rmse', 'mean_relative_bias']]
            .agg(['mean', 'std']))
# Out:
#               amplitude_rmse           mean_relative_bias
#                         mean       std               mean       std
# method
# fixed_OF          148.490729  1.930010          -0.984844  0.017007
# time_shift_OF      68.875578  4.398213          -0.415210  0.041713

# %%
# ── E8: time-shift OF figure ─────────────────────────────────────────────────
if e8_rows:
    e8_agg = (e8_all.groupby('method')[['amplitude_rmse', 'mean_relative_bias']]
              .agg(['mean', 'std']))
    methods = e8_agg.index.tolist()
    x_e8 = np.arange(len(methods))

    fig, axes = plt.subplots(1, 2, figsize=(9, 3.8))
    for ax, metric, ylabel in zip(
            axes,
            ['amplitude_rmse', 'mean_relative_bias'],
            ['Amplitude RMSE', 'Mean relative bias']):
        mu_e8 = e8_agg[metric]['mean'].values
        sd_e8 = e8_agg[metric]['std'].fillna(0).values
        ax.bar(x_e8, mu_e8, yerr=sd_e8, capsize=5, color=BLUE, alpha=0.85,
               error_kw={'lw': 1.5})
        ax.set_xticks(x_e8); ax.set_xticklabels(methods, rotation=15)
        ax.set_ylabel(ylabel)
        ax.set_title(f'E8 — Time-shift OF: {ylabel}')
    fig.tight_layout()
    save_fig(fig, 'e8_timeshift_of.jpg')
    plt.show()
# Out:
#   saved -> results/figures/e8_timeshift_of.jpg

# %% [markdown]
# ---
# ## 11 — E9: EMPCA convergence
#
# *Paper §6.1.*
# χ² must decrease monotonically; convergence expected within O(10-50) iterations.
# Shaded band = std across seeds.

# %%
e9_dfs = []
if CACHE_H5.exists():
    with h5py.File(CACHE_H5, 'r') as h5:
        for sg in cache_groups(h5, 'e3_e9'):
            path = f'e3_e9/{sg}/e9'
            if path in h5:
                df = load_df(h5, path); df['seed'] = sg; e9_dfs.append(df)

if not e9_dfs and _fb:
    e9_dfs = [_fb['b06']['convergence_df'].assign(seed='fallback')]

e9_all = pd.concat(e9_dfs, ignore_index=True)
e9_all['chi2_norm'] = e9_all.groupby(['seed','k','init'])['chi2'].transform(
    lambda s: s / s.iloc[0])

fig, axes = plt.subplots(1, 2, figsize=(10, 4), sharey=True)
kcols = {1: BLUE, 2: ORANGE, 3: GREEN}
for ax, init in zip(axes, ['random', 'svd']):
    sub = e9_all[(e9_all['init'] == init) & e9_all['k'].isin([1,2,3])]
    for k, grp in sub.groupby('k'):
        it = grp.groupby('iteration')['chi2_norm']
        mu = it.mean(); sd = it.std().fillna(0)
        ax.plot(mu.index.values, mu.values, color=kcols[k], label=f'k={k}')
        ax.fill_between(mu.index.values, mu-sd, mu+sd,
                        color=kcols[k], alpha=0.15)
    ax.set_xlabel('iteration'); ax.set_ylabel('normalised chi2')
    ax.set_title(f'init = {init}'); ax.legend(fontsize=9)
fig.suptitle('E9 -- EMPCA convergence  (shading = std across seeds)')
fig.tight_layout()
save_fig(fig, 'e9_convergence.jpg'); plt.show()
# Out:
#   saved -> results/figures/e9_convergence.jpg

# %%
e9_smry_dfs = []
if CACHE_H5.exists():
    with h5py.File(CACHE_H5, 'r') as h5:
        for sg in cache_groups(h5, 'e3_e9'):
            path = f'e3_e9/{sg}/e9/summary'
            if path in h5:
                df = load_df(h5, path); df['seed'] = sg; e9_smry_dfs.append(df)

if e9_smry_dfs:
    e9_smry = pd.concat(e9_smry_dfs, ignore_index=True)
    display(e9_smry.groupby(['k','init'])
            [['iterations_used','iter_to_relative_tol_1e-6']]
            .agg(lambda x: f'{x.mean():.1f} +/- {x.std():.1f}'))
elif _fb:
    display(_fb['b06']['convergence_summary_df'])
# Out:
#          iterations_used iter_to_relative_tol_1e-6
# k init
# 1 random    80.0 +/- 0.0               4.6 +/- 0.5
#   svd       80.0 +/- 0.0               1.0 +/- 0.0
# 2 random    80.0 +/- 0.0               4.2 +/- 0.7
#   svd       80.0 +/- 0.0               1.0 +/- 0.0
# 3 random    80.0 +/- 0.0               6.9 +/- 0.6
#   svd       80.0 +/- 0.0               1.0 +/- 0.0

# %% [markdown]
# ---
# ### E9b — Principal-angle vs EM iteration
#
# *Paper §7.6 and §6.1.*
# Tracks cos(∠(u₁⁽ʳ⁾, s̃)) at each EM step.
# Expected: monotone increase from ~1/√d (random init) to >0.9999 at convergence.
# SVD warm-start should converge in <5 steps.

# %%
# ── E9b: principal-angle vs iteration ────────────────────────────────────────
# Figure pre-generated via standalone script (3 seeds × 200 events × 30 iters).
# Skips recompute if PDF already present.
_e9b_fig = FIG_DIR / 'e9b_principal_angle_vs_iter.jpg'
if _e9b_fig.exists():
    print(f'E9b figure already present: {_e9b_fig.name} — skipping recompute.')
else:
    from empca_TCY_optimized import empca_solver, orthonormalize
    from notebook_support import exact_weighted_subspace, simulate_rank1_batch as _srb9b
    try:
        from empca_equivalence_utils import weighted_cosine, weighted_inner
    except ImportError:
        from src.metrics import weighted_cosine, weighted_inner

    def _tracked_empca(X_f, weights, k, n_iter, init='random', seed=None):
        X_f = np.asarray(X_f, dtype=np.complex128)
        weights = np.asarray(weights, dtype=np.float64)
        if seed is not None: np.random.seed(seed)
        solver = empca_solver(k, X_f, weights)
        if init.lower() == 'svd':
            solver.eigvec = exact_weighted_subspace(X_f, weights, k)['basis_native'].copy()
            solver.coeff = solver.solve_coeff()
        bases = []
        for _ in range(n_iter):
            solver.eigvec = orthonormalize(solver.solve_eigvec(mode='fast'))
            solver.coeff = solver.solve_coeff()
            bases.append(solver.eigvec.copy())
        return bases

    e9b_results = {'random': {nt: [] for nt in ['pink','white','brownian']},
                    'svd':    {nt: [] for nt in ['pink','white','brownian']}}
    for seed in [314159, 271828, 161803]:
        _cfg_e9b = CanonicalConfig(seed=seed).validate()
        for nt in ['pink', 'white', 'brownian']:
            bundle_e9b, _ = _srb9b(_cfg_e9b, n_events=200, amp_range=(0.8, 1.2),
                                    noise_type=nt, noise_power=1.0)
            w_e9b = bundle_e9b.weights_one_sided
            s_tilde = bundle_e9b.template_freq / np.sqrt(
                np.real(weighted_inner(bundle_e9b.template_freq,
                                       bundle_e9b.template_freq, w_e9b)))
            Xtr = bundle_e9b.traces_freq[bundle_e9b.split_indices['train']]
            for init in ['random', 'svd']:
                bases = _tracked_empca(Xtr, w_e9b, k=1, n_iter=30, init=init, seed=seed)
                cosines = [abs(float(np.real(weighted_cosine(b[0], s_tilde, w_e9b)))) for b in bases]
                e9b_results[init][nt].append(cosines)

    fig, axes = plt.subplots(1, 2, figsize=(10, 4), sharey=True)
    nt_colors = {'pink': BLUE, 'white': ORANGE, 'brownian': GREEN}
    for ax, init in zip(axes, ['random', 'svd']):
        for nt in ['pink', 'white', 'brownian']:
            arr = np.array(e9b_results[init][nt])
            mu = arr.mean(0); sd = arr.std(0)
            iters = np.arange(len(mu))
            ax.plot(iters, mu, color=nt_colors[nt], label=nt)
            ax.fill_between(iters, mu-sd, mu+sd, color=nt_colors[nt], alpha=0.15)
        ax.axhline(0.9999, color='gray', ls='--', lw=1, label='pass threshold')
        ax.set_xlabel('EM iteration'); ax.set_ylabel('cos(∠(u₁, s̃))')
        ax.set_title(f'init = {init}'); ax.legend(fontsize=9)
    fig.suptitle('E9b — Principal-angle vs EM iteration  (shading = std, 3 seeds)')
    fig.tight_layout()
    save_fig(fig, 'e9b_principal_angle_vs_iter.jpg'); plt.show()
# Out:
#   saved -> results/figures/e9b_principal_angle_vs_iter.jpg

# %% [markdown]
# ---
# ## 12 — Figure summary
#
# All figures saved to `results/figures/`.
#
# | File | Experiment | Paper section |
# |---|---|---|
# | `psd_audit.jpg` | Real-data PSD audit | §2 preprocessing |
# | `e2_bridge_cosines.jpg` | E2: Theorem 2 (Bridge) | §5.3 |
# | `e3_rank_saturation.jpg` | E3: χ²(k) monotone | §4.4 |
# | `e4_crb_verification.jpg` | E4: CRB | §3.2 |
# | `e5_resolution_scaling.jpg` | E5: σ_E scaling (error bars) | §3.2 |
# | `e6_ablation.jpg` | E6: noise-aware vs iso (error bars) | §7 |
# | `e7_mismatch_curve.jpg` | E7: template mismatch (fixed x-axis) | §3.4 |
# | `e9_convergence.jpg` | E9: convergence (shaded band) | §6.1 |
# | `e1_amplitude_parity.jpg` | E1: EMPCA vs OF amplitude scatter | §7.3 Theorem 1 |
# | `e6_sigma_E_comparison.jpg` | E6b: σ_E noise-aware vs isotropic | §7.5 ablation |
# | `e8_timeshift_of.jpg` | E8: time-shift OF metrics | §7.3 |
# | `e9b_principal_angle_vs_iter.jpg` | E9b: principal-angle vs EM iteration | §7.6 |
# | `psd_audit_simulation.jpg` | Simulation PSD (fallback) | §2 preprocessing |

# %%
print('Figures in:', FIG_DIR)
for f in sorted(FIG_DIR.glob('*.jpg')):
    print(' ', f.name)
# Out:
# Figures in: /Users/wongdowling/Documents/noise-weighted-subspace-reconstruction/results/figures
#   e1_amplitude_parity.jpg
#   e2_bridge_cosines.jpg
#   e3_rank_saturation.jpg
#   e4_crb_verification.jpg
#   e5_resolution_scaling.jpg
#   e6_ablation.jpg
#   e6_sigma_E_comparison.jpg
#   e7_mismatch_curve.jpg
#   e8_timeshift_of.jpg
#   e9_convergence.jpg
#   e9b_principal_angle_vs_iter.jpg
#   p1_sigma_vs_k.jpg
#   p2_snr_spectral_density.jpg
#   p3_cosine_matrix.jpg
#   p4_timing_bias_reduction.jpg
#   p5_ks_pvalue_vs_k.jpg
#   p5_residual_qq.jpg
#   p6_bootstrap_ci_cosines.jpg
#   psd_audit_simulation.jpg

# %% [markdown]
# ---
# ## 13 — Pass/Fail Summary
#
# All numerical pass/fail criteria from E1–E9 in one table.

# %%
# ── Summary: all pass/fail criteria ──────────────────────────────────────────
_summary_rows = []

if 'e1_all' in dir() and e1_all is not None:
    for col, (thr, op) in THRESHOLDS.items():
        if col not in e1_all.columns: continue
        mu_s = e1_all[col].mean(); sd_s = e1_all[col].std()
        _summary_rows.append({
            'exp': 'E1', 'metric': col,
            'mean': round(mu_s, 6), 'std': round(sd_s, 6),
            'threshold': thr, 'op': op,
            'pass': 'PASS' if (mu_s >= thr if op == '>=' else mu_s <= thr) else 'FAIL',
        })

if 'e4_agg' in dir():
    for _, r in e4_agg.iterrows():
        _summary_rows.append({
            'exp': 'E4', 'metric': f"CRB_{r['noise_type']}",
            'mean': round(r['mean_rel_error'], 5), 'std': round(r['std_rel_error'], 5),
            'threshold': 0.05, 'op': '<=', 'pass': r['pass'],
        })

if 'slope_mu' in dir():
    _summary_rows.append({
        'exp': 'E5', 'metric': 'log-log slope',
        'mean': round(slope_mu, 4), 'std': round(slope_sd, 4),
        'threshold': '0.500 ± 0.05', 'op': 'range',
        'pass': 'PASS' if abs(slope_mu - 0.5) < 0.05 else 'FAIL',
    })

if _summary_rows:
    display(pd.DataFrame(_summary_rows).set_index(['exp', 'metric']))
else:
    print('No pass/fail data available — run all experiment cells first.')
# Out:
#                                   mean       std     threshold     op  pass
# exp metric
# E1  weighted_subspace_cosine  0.999419  0.000007        0.9999     >=  FAIL
#     amplitude_correlation     1.000000  0.000000         0.999     >=  PASS
#     median_relative_error     0.001147  0.000030         0.001     <=  FAIL
#     residual_ks_pvalue        1.000000  0.000001          0.05     >=  PASS
# E4  CRB_brownian              0.018180  0.014940          0.05     <=  PASS
#     CRB_pink                  0.030430  0.015970          0.05     <=  PASS
#     CRB_white                 0.035440  0.013360          0.05     <=  PASS
# E5  log-log slope             0.500000  0.000000  0.500 ± 0.05  range  PASS
