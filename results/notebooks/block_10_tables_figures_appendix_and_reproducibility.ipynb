# %% [markdown]
# # Block 10: Tables, Figures, Appendix, and Reproducibility
#
# **Goal**
# Inventory the generated artifacts and centralize a reproducibility manifest for the notebook suite.
#
# **Checklist alignment**
# Wraps the outputs of Blocks 01-09 into a paper-facing inventory.
#
# **Outputs**
# - tables under `results/tables/`
# - figures under `results/figures/`
# - manifests under `results/manifests/`
# - executed notebook copy under `results/notebooks/` when this suite is run with `--execute`

# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt
import pandas as pd

def find_repo_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / "experiment_checklist.md").exists() and (candidate / "implementation").exists():
            return candidate
    raise RuntimeError("Could not locate repo root for notebook execution.")

REPO_ROOT = find_repo_root(Path.cwd().resolve())
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from implementation.notebook_support import *

cfg = CanonicalConfig().validate()
dirs = ensure_results_dirs(cfg)
plt.style.use("seaborn-v0_8-whitegrid")
pd.set_option("display.max_colwidth", 120)

# %%
expected = pd.DataFrame(
    [
        ("block_01", "results/tables/block_01_claim_map.csv"),
        ("block_02", "results/manifests/block_02_split_manifest.json"),
        ("block_03", "results/tables/block_03_e12_real_summary.csv"),
        ("block_04", "results/tables/block_04_e4_crb.csv"),
        ("block_05", "results/tables/block_05_e2_bridge.csv"),
        ("block_06", "results/tables/block_06_e9_convergence.csv"),
        ("block_07", "results/tables/block_07_e6_ablation.csv"),
        ("block_08", "results/tables/block_08_pc_metrics.csv"),
        ("block_09", "results/tables/block_09_e10_nonstationary.csv"),
    ],
    columns=["block_id", "artifact_relpath"],
)
expected["exists"] = expected["artifact_relpath"].map(lambda p: (REPO_ROOT / p).exists())
display(expected)
# Out:
#    block_id                                artifact_relpath  exists
# 0  block_01           results/tables/block_01_claim_map.csv    True
# 1  block_02  results/manifests/block_02_split_manifest.json    True
# 2  block_03    results/tables/block_03_e12_real_summary.csv    True
# 3  block_04              results/tables/block_04_e4_crb.csv    True
# 4  block_05           results/tables/block_05_e2_bridge.csv    True
# 5  block_06      results/tables/block_06_e9_convergence.csv    True
# 6  block_07         results/tables/block_07_e6_ablation.csv    True
# 7  block_08          results/tables/block_08_pc_metrics.csv    True
# 8  block_09   results/tables/block_09_e10_nonstationary.csv    True

# %%
manifest_files = sorted(dirs["manifests"].glob("block_*.json"))
table_files = sorted(dirs["tables"].glob("block_*.*"))
figure_files = sorted(dirs["figures"].glob("block_*.*"))
inventory = pd.DataFrame(
    [{"kind": "manifest", "path": str(path.relative_to(REPO_ROOT))} for path in manifest_files]
    + [{"kind": "table", "path": str(path.relative_to(REPO_ROOT))} for path in table_files]
    + [{"kind": "figure", "path": str(path.relative_to(REPO_ROOT))} for path in figure_files]
)
display(inventory)
# Out:
#         kind                                                      path
# 0   manifest           results/manifests/block_01_execution_rules.json
# 1   manifest            results/manifests/block_02_split_manifest.json
# 2   manifest                results/manifests/block_03_of_summary.json
# 3   manifest              results/manifests/block_03_real_summary.json
# 4   manifest         results/manifests/block_04_synthetic_summary.json
# 5   manifest           results/manifests/block_04_theorem_summary.json
# 6   manifest            results/manifests/block_05_bridge_summary.json
# 7   manifest    results/manifests/block_06_rank_selection_summary.json
# 8   manifest          results/manifests/block_07_ablation_summary.json
# 9   manifest                results/manifests/block_08_pc_summary.json
# 10  manifest        results/manifests/block_09_robustness_summary.json
# 11  manifest  results/manifests/block_10_reproducibility_manifest.json
# 12     table                     results/tables/block_01_claim_map.csv
# 13     table                  results/tables/block_02_data_sources.csv
# 14     table                     results/tables/block_02_psd_audit.csv
# 15     table              results/tables/block_03_e12_real_summary.csv
# 16     table              results/tables/block_03_rank1_comparison.csv
# 17     table                   results/tables/block_03_real_bridge.csv
# 18     table         results/tables/block_03_real_rank1_amplitudes.csv
# 19     table              results/tables/block_04_e1_rank1_summary.csv
# 20     table                        results/tables/block_04_e4_crb.csv
# 21     table                 results/tables/block_04_e5_resolution.csv
# 22     table                results/tables/block_04_synthetic_grid.csv
# 23     table              results/tables/block_05_coordinate_norms.csv
# 24     table                     results/tables/block_05_e2_bridge.csv
# 25     table               results/tables/block_06_e3_monotonicity.csv
# 26     table                results/tables/block_06_e9_convergence.csv
# 27     table                results/tables/block_06_rank_selection.csv
# 28     table                      results/tables/block_07_ablation.csv
# 29     table                   results/tables/block_07_e6_ablation.csv
# 30     table                 results/tables/block_07_e7_bias_curve.csv
# 31     table                   results/tables/block_07_e7_mismatch.csv
# 32     table                 results/tables/block_07_e8_time_shift.csv
# 33     table               results/tables/block_08_pc_correlations.csv
# 34     table                    results/tables/block_08_pc_metrics.csv
# 35     table             results/tables/block_09_e10_nonstationary.csv
# 36     table                 results/tables/block_09_e11_artifacts.csv
# 37     table          results/tables/block_09_multichannel_summary.csv
# 38     table                    results/tables/block_09_robustness.csv
# 39    figure                    results/figures/block_02_psd_audit.png
# 40    figure     results/figures/block_03_real_amplitude_histogram.png
# 41    figure           results/figures/block_03_real_rank1_scatter.png
# 42    figure        results/figures/block_04_e5_resolution_scaling.png
# 43    figure               results/figures/block_05_bridge_cosines.png
# 44    figure                  results/figures/block_06_convergence.png
# 45    figure              results/figures/block_06_rank_saturation.png
# 46    figure                  results/figures/block_07_e6_ablation.png
# 47    figure            results/figures/block_07_e7_mismatch_curve.png
# 48    figure            results/figures/block_08_pc_overlap_matrix.png
# 49    figure            results/figures/block_09_e10_nonstationary.png
# 50    figure                results/figures/block_09_e11_artifacts.png

# %%
manifest_path = dirs["manifests"] / "block_10_reproducibility_manifest.json"
save_json(
    {
        "canonical_config": config_as_frame(cfg).to_dict(orient="records"),
        "expected_artifacts": expected.to_dict(orient="records"),
        "present_inventory": inventory.to_dict(orient="records"),
    },
    manifest_path,
)
pd.DataFrame([manifest_row("block_10", "packaging", str(manifest_path.relative_to(REPO_ROOT)), cfg)])
# Out:
#    block_id     regime  \
# 0  block_10  packaging
#
#                                                 output_path    seed  \
# 0  results/manifests/block_10_reproducibility_manifest.json  314159
#
#    trace_len  pretrigger
# 0      32768        4000
