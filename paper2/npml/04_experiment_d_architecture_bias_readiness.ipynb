# %% [markdown]
# # Experiment D: Architecture Bias Readiness
#
# The current repository contains relevant backbones, but not a runnable reconstruction training stack for this experiment.
# This notebook makes that explicit so the talk can separate completed evidence from code still needed.

# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt
import pandas as pd

ROOT = Path.cwd().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from npml_support import *

dirs = ensure_npml_dirs()

# %%
status_df = experiment_d_status_table()
inventory_df = audit_src_models()
display(status_df)
display(inventory_df[inventory_df["experiment"].isin(["D", "D/E"])])

save_dataframe(status_df, "04_architecture_bias_status.csv")
# Out:
#             model  code_present  runnable_now  \
# 0       Linear AE          True          True
# 1          CNN AE          True         False
# 2  Transformer AE          True         False
#
#                                                                                                                             notes
# 0                            Exact weighted linear optimum available via implementation.notebook_support exact_weighted_subspace.
# 1          Backbone exists in src/CNN/resnet_1d.py, but torch is missing and there is no autoencoder reconstruction head/trainer.
# 2  Transformer backbones exist, but depend on torch + reconstruction.training.muon and have no reconstruction experiment harness.
#   experiment                    model_family                                                     path   status  runnable_now  \
# 3          D                       Linear AE  implementation.notebook_support exact_weighted_subspace  partial          True
# 4          D                    CNN backbone                                     src/CNN/resnet_1d.py  blocked         False
# 5        D/E                  model_original                        src/transformer/model_original.py  blocked         False
# 6        D/E                  model_pairwise                        src/transformer/model_pairwise.py  blocked         False
# 7        D/E  model_pairwise_channel_masking        src/transformer/model_pairwise_channel_masking.py  blocked         False
# 8        D/E       model_triangular_pairwise             src/transformer/model_triangular_pairwise.py  blocked         False
#
#                                                                                                                                                              notes
# 3                                                          Exact weighted SVD gives the linear-AE optimum, but there is no standalone training wrapper under src/.
# 4                       Torch installed? False. Local norm dependency present? False. File defines a ResNet backbone, not a reconstruction autoencoder or trainer.
# 5  Requires torch and reconstruction.training.muon; torch installed=False, muon module present=True. These files also define transformer backbones only, not en...
# 6  Requires torch and reconstruction.training.muon; torch installed=False, muon module present=True. These files also define transformer backbones only, not en...
# 7  Requires torch and reconstruction.training.muon; torch installed=False, muon module present=True. These files also define transformer backbones only, not en...
# 8  Requires torch and reconstruction.training.muon; torch installed=False, muon module present=True. These files also define transformer backbones only, not en...
# PosixPath('/Users/wongdowling/Documents/noise-weighted-subspace-reconstruction/paper2/npml/tables/04_architecture_bias_status.csv')

# %%
plot_df = inventory_df[inventory_df["experiment"].isin(["D", "D/E"])].copy()
fig = plot_readiness(plot_df, "Experiment D/E code readiness")
save_figure(fig, "04_architecture_bias_readiness.png")
plt.show()
plt.close(fig)
# Out:
# /var/folders/y6/2zvmjscx2s18w96j7qx32nnr0000gn/T/ipykernel_24449/2049591640.py:4: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
